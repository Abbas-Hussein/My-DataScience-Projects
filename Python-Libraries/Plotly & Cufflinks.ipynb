# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 5.24.1

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# DATA
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -1.287113 -1.352233  0.844733 -0.873022
# 1  0.649015  1.399255 -1.567652 -2.752301
# 2 -2.278163 -0.755416 -2.955725 -0.505867
# 3 -0.398024 -0.676555  0.443673 -0.584652
# 4 -1.007919  1.976137  2.363575  1.017341

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.plot()
plt.show()

# %%
df.iplot()
plt.show()

# %%
#Create different types of plots
df.iplot(kind='scatter',x='A',y='B') # this looks funny

# %%
# so we specify the mode
df.iplot(kind='scatter',x='A',y='B',mode='markers')

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=20)

# %%
df2.iplot(kind='bar',x='Category',y='Values')

# %%
df.iplot(kind='box')

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
# we can use a surface plot if we want to create a 3 dimensional plot of these variables
df3.iplot(kind='surface',colorscale='rdylbu')

# %%
df['A'].iplot(kind='hist',bins=50)

# %%
df.iplot(kind='hist',bins=50) # Here we called the whole dataframe, hence we'll get overlaps,
#but you can go to the legends and turn them on and off to compare them to each other (i.e the overlaps)

# %%
#df[['A','B']].iplot(kind='spread') # This will give a plot and a subplot (both lineplot and spreadplot) 
# spreadplot gives error because it is deprecated

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')

# %%
df.scatter_matrix()
